# %% [markdown]
# # Automated Document Scraper for Multiple Formats
#
# ### Project Overview
# In this notebook, we build a document scraper designed to search the web, locate documents in various formats, and download them locally. This automated approach allows for the efficient collection and organization of a large volume of documents across multiple file types, including PDF, DOCX, TXT, CSV, and HTML, based on a specific subject area.
#
# ### Objective
# The goal of this project is to create a tool that:
# 1. **Takes a user-defined subject area** as input.
# 2. **Searches the web** for documents related to the subject area, focusing on one file format at a time.
# 3. **Downloads and organizes** the documents locally in a structured manner.
# 4. **Processes** the content of each file, converting it to text format if necessary (e.g., PDFs and DOCX files).
#
# This notebook will guide you through the steps involved in setting up the scraper, executing it, and managing the downloaded files effectively.
#
# ### Steps to Follow
# 1. **Input Subject Area**: You will be prompted to enter the topic or keyword related to the documents you wish to scrape.
# 2. **Format-Specific Search**: The program searches Google for files of each specified format (PDF, DOCX, TXT, CSV, and HTML) relevant to the subject area.
# 3. **File Download and Organization**: Files are downloaded into a specified directory, and their content is extracted if applicable (e.g., converting PDFs and DOCX files to plain text).
# 4. **Error Handling**: The code includes error handling to manage issues like network errors, unsupported formats, or inaccessible URLs.
#
# ### Prerequisites
# The following Python packages are used in this notebook:
# - `requests`: for downloading files.
# - `googlesearch-python`: to search Google for relevant document URLs.
# - `pdfplumber`: for extracting text from PDF files.
# - `python-docx`: for extracting text from DOCX files.
# - `pandas`: for handling CSV data.
# - `beautifulsoup4`: for parsing HTML content.
#
# Please ensure these packages are installed by running:
# ```python
# !pip install requests googlesearch-python pdfplumber python-docx pandas beautifulsoup4
# ```
#
# ### Important Notes
# 1. **Terms of Use**: Scraping Google search results and downloading documents must comply with the terms of service of the respective websites and Google itself.
# 2. **File Organization**: All files will be organized in a local directory named "downloaded_files" within the notebook’s working directory.
# 3. **Scalability**: Adjustments can be made to the number of search results per file format to better suit the scale of your project.
#
# After completing the setup, run the code below to begin the search and download process.

# %%
import os
import requests
from googlesearch import search
import pdfplumber
from docx import Document
import pandas as pd
from bs4 import BeautifulSoup
import re

# %%
# Define the directory where files will be saved
save_dir = "downloaded_files"
os.makedirs(save_dir, exist_ok=True)

# Ask the user for the subject area
subject_area = input("Enter the subject area you want to search: ")


# Define the formats to search for and download
formats = ["pdf", "docx", "txt", "csv", "html"]

# %%
# Define the formats to search for and download
formats = ["pdf", "docx", "txt", "csv", "html"]

# Sanitize file names
def sanitize_filename(filename):
    return re.sub(r'[<>:"/\\|?*]', '_', filename)

# Function to download and save documents based on format
def download_file(url, save_path):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            with open(save_path, "wb") as f:
                f.write(response.content)
            print(f"Downloaded: {save_path}")
        else:
            print(f"Failed to download: {url}")
    except Exception as e:
        print(f"Error downloading {url}: {e}")

# Function to extract and organize file content
def process_document(url, file_extension, format_dir):
    file_name = sanitize_filename(url.split('/')[-1])
    file_path = os.path.join(format_dir, file_name)  # Keep original extension

    # Download the file
    download_file(url, file_path)

    # Process based on file format
    if file_extension == "pdf":
        try:
            with pdfplumber.open(file_path) as pdf:
                text = "\n".join(page.extract_text() for page in pdf.pages if page.extract_text())
                with open(f"{file_path}.txt", "w", encoding="utf-8") as f:
                    f.write(text)
        except Exception as e:
            print(f"Error processing PDF {file_name}: {e}")

    elif file_extension == "docx":
        try:
            doc = Document(file_path)
            text = "\n".join([para.text for para in doc.paragraphs])
            with open(f"{file_path}.txt", "w", encoding="utf-8") as f:
                f.write(text)
        except Exception as e:
            print(f"Error processing DOCX {file_name}: {e}")

    elif file_extension == "csv":
        try:
            df = pd.read_csv(file_path)
            df.to_csv(file_path, index=False)
        except Exception as e:
            print(f"Error processing CSV {file_name}: {e}")

    elif file_extension == "html":
        try:
            response = requests.get(url)
            soup = BeautifulSoup(response.text, "html.parser")
            with open(f"{file_path}.txt", "w", encoding="utf-8") as f:
                f.write(soup.get_text())
        except Exception as e:
            print(f"Error processing HTML {file_name}: {e}")

# Function to search and download 1000 documents by format
def search_and_download_by_format(subject, file_format):
    query = f"{subject} {file_format} filetype:{file_format}"
    downloaded_count = 0
    
    # Create a subfolder for the current file format
    format_dir = os.path.join(base_dir, file_format)
    os.makedirs(format_dir, exist_ok=True)

    for url in search(query, num_results=100):  # Fetching in batches
        if 'robots.txt' in url:
            continue
        print(f"Found URL: {url}")
        process_document(url, file_format, format_dir)
        downloaded_count += 1
        if downloaded_count >= 10:
            break
    print(f"Completed downloading {downloaded_count} {file_format.upper()} files.")

# Iterate through formats, searching and downloading each one
for file_format in formats:
    print(f"\nSearching and downloading {file_format.upper()} files for: {subject_area}")
    search_and_download_by_format(subject_area, file_format)
# Out:
# Searching and downloading PDF files for: Geological Engineering
# Found URL: https://vardhaman.org/wp-content/uploads/2021/03/ENGINEERING-GEOLOGY-1.pdf
# Downloaded: downloaded_files\pdf\ENGINEERING-GEOLOGY-1.pdf
# Found URL: https://edisciplinas.usp.br/pluginfile.php/5587989/mod_resource/content/2/A_Geology_for_Engineers_Seventh_Edition.pdf
# Downloaded: downloaded_files\pdf\A_Geology_for_Engineers_Seventh_Edition.pdf
# Found URL: https://geomuseu.ist.utl.pt/SEMINAR2012/Livros/EngenhariaGeologica.pdf
# Downloaded: downloaded_files\pdf\EngenhariaGeologica.pdf
# Found URL: https://hostnezt.com/cssfiles/geology/Engineering%20Geology%20-%20Principles%20and%20Practice.pdf
# Downloaded: downloaded_files\pdf\Engineering%20Geology%20-%20Principles%20and%20Practice.pdf
# Found URL: https://www.routledge.com/rsc/downloads/SW3524_Sample.pdf?srsltid=AfmBOop0zuU8HMRuFj1J7wzOPj7pmJPU0fnE8no_NU-k4lKR5CbiR9cT
# Downloaded: downloaded_files\pdf\SW3524_Sample.pdf_srsltid=AfmBOop0zuU8HMRuFj1J7wzOPj7pmJPU0fnE8no_NU-k4lKR5CbiR9cT
# Found URL: https://pdhonline.com/courses/c248/GeolMan-v1-all.pdf
# Downloaded: downloaded_files\pdf\GeolMan-v1-all.pdf
# Found URL: https://geoeng.ubc.ca/sites/default/files/GeoEng-Student-Guide-2023-24.pdf
# Downloaded: downloaded_files\pdf\GeoEng-Student-Guide-2023-24.pdf
# Found URL: https://www.geokniga.org/bookfiles/geokniga-engineering-geology.pdf
# Downloaded: downloaded_files\pdf\geokniga-engineering-geology.pdf
# Found URL: https://www.aybu.edu.tr/bolumroot/contents/muhendislik_insaat/files/GEOLOGY%20FOR%20CIVIL%20ENGINEERING.pdf
# Downloaded: downloaded_files\pdf\GEOLOGY%20FOR%20CIVIL%20ENGINEERING.pdf
# Found URL: https://geoeng.ubc.ca/sites/default/files/GeoEngStudentGuide2021-22.pdf
# Downloaded: downloaded_files\pdf\GeoEngStudentGuide2021-22.pdf
# Completed downloading 10 PDF files.
#
# Searching and downloading DOCX files for: Geological Engineering
# Found URL: https://www.apegs.ca/assets/20-geological-engineering-2022.docx
# Downloaded: downloaded_files\docx\20-geological-engineering-2022.docx
# Found URL: https://people.wou.edu/~taylors/g322/Engineering%20geology%20overview.docx
# Downloaded: downloaded_files\docx\Engineering%20geology%20overview.docx
# Found URL: https://libraries.wsu.edu/sites/default/files/cd-geology.docx
# Downloaded: downloaded_files\docx\cd-geology.docx
# Found URL: https://methodist.edu.in/web/uploads/files/UNIT_1_INTRODUCTION%20123%20.docx
# Downloaded: downloaded_files\docx\UNIT_1_INTRODUCTION%20123%20.docx
# Found URL: https://fns.uniba.sk/fileadmin/prif/zahranicie/mgr/mgr_geology/Engineeringg-Geological_Research_and_Survey.docx
# Downloaded: downloaded_files\docx\Engineeringg-Geological_Research_and_Survey.docx
# Found URL: https://digitalmeasures.utep.edu/ai/doser/schteach/geol3321-fall-2021-lecturesyllabus-v1-1.docx
# Downloaded: downloaded_files\docx\geol3321-fall-2021-lecturesyllabus-v1-1.docx
# Found URL: https://wp.ufpel.edu.br/crinter/files/2018/10/Geological-Engineering.docx
# Downloaded: downloaded_files\docx\Geological-Engineering.docx
# Found URL: https://ects.ogu.edu.tr/dosyalar/170-Jeoloji%20M%C3%BChendisli%C4%9Fi%20Y%C3%BCksek%20Lisans%20Program%C4%B1/Information%20Package%20and%20Course%20Catalogue.docx
# Downloaded: downloaded_files\docx\Information%20Package%20and%20Course%20Catalogue.docx
# Found URL: https://wnoz.uwr.edu.pl/wp-content/uploads/sites/285/2023/02/lib-english-for-geologists-english-1.docx
# Downloaded: downloaded_files\docx\lib-english-for-geologists-english-1.docx
# Found URL: https://www.uoanbar.edu.iq/EngineeringCollege//catalog/Engineering%20Geology%20modifed[1].docx
# Downloaded: downloaded_files\docx\Engineering%20Geology%20modifed[1].docx
# Completed downloading 10 DOCX files.
#
# Searching and downloading TXT files for: Geological Engineering
# Found URL: https://geoscan.nrcan.gc.ca/text/geoscan/readme/of6550-e.txt
# Downloaded: downloaded_files\txt\of6550-e.txt
# Found URL: https://courses.edx.org/asset-v1:CurtinX+TBOMx+2T2015+type@asset+block/3.2_Geotechnical_Engineering.txt
# Downloaded: downloaded_files\txt\3.2_Geotechnical_Engineering.txt
# Found URL: https://www.nsf.gov/pubs/2003/engcms002/engcms002.txt
# Downloaded: downloaded_files\txt\engcms002.txt
# Found URL: https://www.geosociety.org/data/sections/sc.txt
# Downloaded: downloaded_files\txt\sc.txt
# Found URL: https://documents1.worldbank.org/curated/en/241051619161798594/text/Geotechnical-Risk.txt
# Downloaded: downloaded_files\txt\Geotechnical-Risk.txt
# Found URL: https://archive.org/stream/geologicengineer97sanf/geologicengineer97sanf_djvu.txt
# Downloaded: downloaded_files\txt\geologicengineer97sanf_djvu.txt
# Found URL: https://www3.carleton.ca/calendars/archives/grad/9394/program_descriptions/engineering/civil_engineering.txt
# Downloaded: downloaded_files\txt\civil_engineering.txt
# Found URL: https://pubs.usgs.gov/circ/c1244/c1244.txt
# Downloaded: downloaded_files\txt\c1244.txt
# Found URL: https://www.gutenberg.org/files/27842/27842-8.txt
# Downloaded: downloaded_files\txt\27842-8.txt
# Found URL: https://www.isca.me/IJES/Archive/v5/i12/text.txt
# Downloaded: downloaded_files\txt\text.txt
# Completed downloading 10 TXT files.
#
# Searching and downloading CSV files for: Geological Engineering
# Found URL: https://mmsd.nrcan-rncan.gc.ca/PDF/ExploTable-f2023-en.csv
# Downloaded: downloaded_files\csv\ExploTable-f2023-en.csv
# Found URL: https://www.osti.gov/etdeweb/api/record-export/21590774?format=csv
# Downloaded: downloaded_files\csv\21590774_format=csv
# Found URL: https://www.onetonline.org/find/descriptor/result/2.C.4.b/Physics.csv?fmt=csv
# Downloaded: downloaded_files\csv\Physics.csv_fmt=csv
# Found URL: https://www.statcan.gc.ca/en/subjects/standard/crdc/2020v2/CRDC-CCRD-2020-FOR-DDR-ElementV2-eng.csv
# Downloaded: downloaded_files\csv\CRDC-CCRD-2020-FOR-DDR-ElementV2-eng.csv
# Found URL: https://open.canada.ca/data/dataset/eeb3e442-9f19-4d12-8b38-c488fe4f6e5e/resource/bc6c40c7-1ec4-47ec-a0ad-53df2fe7f9ad/download/interest-en_oasis_2023_v1.0.csv
# Downloaded: downloaded_files\csv\interest-en_oasis_2023_v1.0.csv
# Found URL: https://www.onetonline.org/find/descriptor/result/2.C.3.b/Engineering_and_Technology.csv?fmt=csv
# Downloaded: downloaded_files\csv\Engineering_and_Technology.csv_fmt=csv
# Found URL: https://epi.grants.cancer.gov/physical/met/ocs-met_table06.csv
# Downloaded: downloaded_files\csv\ocs-met_table06.csv
# Found URL: https://www.onemine.org/documents/geology-development-and-construction-of-a-ground-water-supply/citation/csv
# Downloaded: downloaded_files\csv\csv
# Found URL: https://ero.ontario.ca/notice/019-7598/comments/comments.csv?_format=csv
# Downloaded: downloaded_files\csv\comments.csv__format=csv
# Found URL: https://softwaresaved.github.io/international-survey-2022/csv/academic_field_edu_germany.csv
# Downloaded: downloaded_files\csv\academic_field_edu_germany.csv
# Completed downloading 10 CSV files.
#
# Searching and downloading HTML files for: Geological Engineering
# Found URL: https://ucalendar.uwaterloo.ca/2324/COURSE/course-GEOE.html
# Downloaded: downloaded_files\html\course-GEOE.html
# Found URL: https://www.unb.ca/academics/programs/engineering/geological_sj.html
# Downloaded: downloaded_files\html\geological_sj.html
# Found URL: https://www.unb.ca/academics/programs/engineering/geological.html
# Downloaded: downloaded_files\html\geological.html
# Found URL: https://academic-calendar-archive.uwaterloo.ca/undergraduate-studies/2023-2024/page/ENG-Geological-Engineering.html
# Downloaded: downloaded_files\html\ENG-Geological-Engineering.html
# Found URL: https://www.canadian-universities.net/Universities/Programs/Geological_Engineering.html
# Downloaded: downloaded_files\html\Geological_Engineering.html
# Found URL: https://ca.indeed.com/q-geological-engineering-l-british-columbia-jobs.html
# Failed to download: https://ca.indeed.com/q-geological-engineering-l-british-columbia-jobs.html
# Found URL: https://und.edu/programs/geological-engineering-bs/index.html
# Downloaded: downloaded_files\html\index.html
# Found URL: https://www.ualberta.ca/en/engineering/civil-environmental-engineering/research/geotechnical-and-geoenvironmental.html
# Downloaded: downloaded_files\html\geotechnical-and-geoenvironmental.html
# Found URL: https://www.dal.ca/faculty/engineering/civil-resource/research/geotechnical.html
# Downloaded: downloaded_files\html\geotechnical.html
# Found URL: https://ca.indeed.com/q-geological-engineer-l-ontario-jobs.html
# Failed to download: https://ca.indeed.com/q-geological-engineer-l-ontario-jobs.html
# Completed downloading 10 HTML files.
